# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 18     |  |
# | :-------------|:-------------|
# | Adam Echant Hamdioui  | 6563031 |
# | Abel van Oord| 6580920 |
# | Aragon van Doesburg| 6394485|

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 18     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 12.00  | Aragon |
# | ontwerp-eis berekenen| 12.15 | Abel en Adam|
# | Sanity check laten zien  | 12.30 | hele groep |
# | Pauze 1 | 12.30-13.30 | hele groep |
# | Meetopstelling afhebben| 14.30 | hele groep|
# | Klaar met meten | 16.00 | Hele groep|
# | Laatste Iteratie | 16.15| Hele groep|

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) |4  |
# | hoe lang voor één meting | 7 minuten |
# | verwacht nauwkeurigheid meting |op 1 decimaal nauwkeurig  |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
# Bereken hier je benodigde kantelfrequentie
g = 9.81
VerhoudingAmAv= -1/3 # - door absoluut
omega= 5
Kantelfreuquentie= omega/2
print("De benodigde kantelfrequentie is: ", Kantelfreuquentie,'Hz')
# Out:
# De benodigde kantelfrequentie is:  2.5 Hz

# %%
# Voeg hier je plot in
def func(w,omega):
    return np.abs(1/(1-((w)**2/omega**2)))

wplot=np.linspace(0,20,1000)


plt.loglog(wplot,func(wplot,Kantelfreuquentie))
plt.xlabel('log Frequentie (Hz)')
plt.ylabel('log|Aout/Ain| ')
plt.show()

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.

dx= 9.81/(2*math.pi*Kantelfreuquentie)**2
print(dx, 'm')
# Out:
# 0.039758432461253344 m

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().
g=9.81
def func2(m,dx,g):
    return m*g/dx

mplot=np.linspace(0.1,10,1000)

plt.plot(mplot,func2(mplot,dx,g), label= '1dx')
plt.plot(mplot,func2(mplot,dx*2,g), label= '2dx')
plt.plot(mplot,func2(mplot,dx*5,g), label= '5dx')
plt.legend()
plt.xlabel('Massa (kg)')
plt.ylabel('Veerconstante (N/m)')
plt.show()



print(func2(0.6,dx,g)) # Veerconstante
# Out:
# 148.04406601634037

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - De massa verhogen (volgens $\Delta x$ = ($m * g$)/$c$ )
# - De veerconstante verlagen
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 0.04m

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="Schets1.jpeg" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# **Ongeveer 0.2 m**
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# **Ja**
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# **34.5 cm**
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# **Ja**
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# **Ja**
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
# Voeg hier je plot in.

def func(w,omega):
    return np.abs(1/(1-((w)**2/omega**2)))

wplot=np.linspace(0,20,1000)

Frequenties= np.array([5.4,7.2,7.5,4.1,8.4,10.2,6.5])
Frequentessorted= np.sort(Frequenties)*2*np.pi
def func3(g,dx):
    return np.sqrt(g/dx)

omega_r = func3(g,0.20)

plt.loglog(wplot,func(wplot,Kantelfreuquentie),label='theoretische data')
plt.loglog(wplot,func(wplot,omega_r), label= 'gemeten data')
plt.xlabel('log Frequentie (Hz)')
plt.ylabel('log|Aout/Ain| ')
plt.legend()
plt.show()

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
# Voeg hier je plots in.

Frequenties= np.array([5.4,7.2,7.5,4.1,8.4,10.2,6.5,1.2,2/3,3.3])
Frequentessorted= np.sort(Frequenties)
Amplitudes= np.array([0.16/0.06,1.3/0.53,0.25/1.12,0.19/1.12,0.12/1.81,0.23/2.8,0.43/4.85,0.34/5.82,0.41/6.08,0.26/6.31])

def func(w,omega):
    return np.abs(1/(1-((w)**2/omega**2)))

wplot=np.linspace(0,100,1000)


def func3(g,dx):
    return np.sqrt(g/dx)

omega_r = func3(g,0.20)/(2*np.pi)

Ampl_err= 0.05

amps1 = np.array([0.21,1.8,0.2,0.14,0.08,0.18,0.38,0.29,0.39,0.21])
amps2 = np.array([0.06,0.48,1.08,1.08,1.76,2.3,4.8,5.77,6.03,6.26])

erramps = Amplitudes*np.sqrt((Ampl_err/amps1)**2 + (Ampl_err/amps2)**2)

freqerr = np.array([1/6,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05,0.05])

plt.figure(figsize=(15,15))
plt.loglog(wplot,func(wplot,Kantelfreuquentie),label='theoretische data')
plt.loglog(wplot,func(wplot,omega_r), label= 'gemeten data')
plt.loglog(Frequentessorted,Amplitudes, 'o',label= 'gemeten data')
plt.errorbar(Frequentessorted, Amplitudes,xerr=freqerr ,yerr=erramps, fmt='o', label='gemeten data met foutbalken')
plt.xlim(10**-2,10**3)
plt.xlabel('log Frequentie (Hz)')

plt.ylabel('log|Aout/Ain| ')
plt.legend()
plt.show()

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %%
# Als je met Python je resultaten wil laten zien: voeg hier je code in.

# %% [markdown]
# #### Als je je figuren onderweg opgeslagen hebt, kan je ze hier invoegen:
# <img src="tudelftLogo.png" width="400">
# <img src="tudelftLogo.png" width="400">
